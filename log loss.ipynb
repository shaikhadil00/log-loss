# %% [markdown]
# ![Screenshot%202024-06-01%20112942.png](attachment:Screenshot%202024-06-01%20112942.png)

# %% [markdown]
# # Log-Loss formula

# %% [markdown]
# ![Screenshot%202024-06-01%20120851.png](attachment:Screenshot%202024-06-01%20120851.png)

# %% [markdown]
# # HOW TO CALCULATE LOG-LOSS

# %% [markdown]
# ![Screenshot%202024-06-01%20121011.png](attachment:Screenshot%202024-06-01%20121011.png)

# %% [markdown]
# # GRAPHICAL REPRESENTATION

# %% [markdown]
# ![Screenshot%202024-06-01%20121356.png](attachment:Screenshot%202024-06-01%20121356.png)

# %% [markdown]
# 1].The relationship between the graph and log loss and predicted probability is inversely proportional.
#
# 2].As the predicted probability gets closer to the true label (0 or 1), the log loss decreases towards 0.
#
# 3].AS the model becomes more certain and accurate in its predictions,the log loss decreases, indicating better performance
#
# 4]. Therefore, the graph of log loss versus predicted probability typically shows a decreasing trend.
#
# 5].AS the predicted probability aligns more closely with the true label.
